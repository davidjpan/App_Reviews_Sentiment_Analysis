# %%
import pandas as pd
import os
import numpy as np  
import re  
import nltk  
from sklearn.datasets import load_files  
nltk.download('stopwords')  
import pickle  
from nltk.corpus import stopwords  
from sklearn.ensemble import RandomForestClassifier
# Out:
# [nltk_data] Downloading package stopwords to /Users/jpan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
os.chdir(r'/Users/jpan/Environments/macys_reviews/')

baddf = pd.read_csv("macys_597.csv", sep='\t')
baddf = baddf.drop(columns=['Unnamed: 0', 'Ratings'])
wholedf = pd.read_csv("macys_5000.csv", sep='\t')
wholedf = wholedf.drop(columns=['Unnamed: 0'])
gooddf = pd.read_csv("macys_4403.csv")
gooddf = gooddf.drop(columns=['Unnamed: 0', 'Ratings'])

# %%
# Read each comment in the dataframe to either pos or neg folder
os.chdir(r'/Users/jpan/Environments/macys_reviews/txt_sentoken/neg')
for i in range(597):
    fh = open(str(i+1) + '_bad.txt', 'w')
    fh.write(''.join(list(baddf['Comments'][i])))
    fh.close()
os.chdir(r'/Users/jpan/Environments/macys_reviews/txt_sentoken/pos')
for i in range(4403):
    fh = open(str(i+1) + '_good.txt', 'w')
    fh.write(''.join(list(gooddf['Comments'][i])))
    fh.close()

# %%
macys_data = load_files(r"/Users/jpan/Environments/macys_reviews/txt_sentoken")  
X, y = macys_data.data, macys_data.target

# %%
# Clean text
documents = []

from nltk.stem import WordNetLemmatizer

stemmer = WordNetLemmatizer()

for sen in range(0, len(X)):  
    # Remove all the special characters
    document = re.sub(r'\W', ' ', str(X[sen]))

    # remove all single characters
    document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)

    # Remove single characters from the start
    document = re.sub(r'\^[a-zA-Z]\s+', ' ', document) 

    # Substituting multiple spaces with single space
    document = re.sub(r'\s+', ' ', document, flags=re.I)

    # Removing prefixed 'b'
    document = re.sub(r'^b\s+', '', document)

    # Converting to Lowercase
    document = document.lower()

    # Lemmatization
    document = document.split()

    document = [stemmer.lemmatize(word) for word in document]
    document = ' '.join(document)

    documents.append(document)

# %%
documents
# Out:
# ['very convenient thank you',
#  'excllent every1 should use macys aap',
#  u'here we go again star reward are constantly pending called waited 20 min they said it would be fixed in couple of day that wa 7 day ago so the reward are basically gone if that why you shop especially during double day beware no one is helping with this problem',
#  'very good app and easy to use recommend',
#  'pretty good',
#  u'great app everything at my fingertip you',
#  'always happy with macy great quality and value',
#  u'like the fact don have to get out of my house to run to the mall to get the discount and sometimes the sale is is even better online in comparison with the store use the app quite often',
#  'can open app',
#  u'it wa very exciting and very detailed about everything they have in store and online',
#  'super slow bill pay is horrible',
#  u'i wa looking for easy way to order and this app wa awesome and very easy to utilize',
#  u'i ve ordered michael kor jacket and have not received any news or reply in over week',
#  u'great experience few stall out or shut down',
#  u'wish could had got my boot before they went of sale but still love them',
#  'easy and efficient to use',
#  u'i like the product that you have and the sale you have and variety of them',
#  u'cannot get into site always technical difficulty',
#  'love it especially being overseas working everything arrives fast and in perfect condition',
#  u'constantly crashing am unable to complete an order downloaded this app while ago and it seems like there are constantly problem with it',
#  'easy to follow',
#  'not happy with this new app whoever speak to is not happy either we need our old one back too much confusion big waste of time',
#  u'it ha been so useful in helping me do my christmas shopping this year such wonderful sale',
#  u'i tryna update wat doe it cost vfb ta update installed now cant get da latest news or new stuff dat shud ta have ta betta my service from wow wat load of cramp',
#  'great site',
#  u'convenient nice brand at reasonable price menu is easy to navigate and fast delivery',
#  'i love the app it is super easy to use very convenient',
#  u'your bargain are well on point and nice reminder for those of u that don shop often',
#  'macy is my everything',
#  u'love the reward and off item',
#  u'i am not receiving email',
#  'good',
#  'i love macys',
#  'very informative and detailed love it',
#  'great app',
#  'very well organized and responsive app',
#  'the best idem ever seen like man stuff',
#  'all the time active great service',
#  'easy and convenient shopping',
#  u'have not ordered anything just yet hope you carry sporting good',
#  'good',
#  'i enjoy using this app very herfull',
#  'always show what looking for fast delivery love it',
#  'best department store app',
#  'app doesn work',
#  'great app for shopping',
#  'i love shopping online and picking up the same day',
#  'i love macy they have everything you need an more',
#  'i fresh from the flo up',
#  u'app ha been helpful with knowing when to expect delivery of purchase and providing holiday gift idea',
#  'easy',
#  'love it great for shopping',
#  'i love macy app the experience of online shopping using this app is so accessible the app is easy to navigate way to go great job keep it up thanks macy',
#  'app is well laid out and easy to use',
#  u'keep telling me the app is not supported anymore what give',
#  'nice',
#  'great app',
#  u'when can enjoy going to macy store enjoy because everythings they sell is amazing my friend ask me where buy or have bought my clothes and recommended this store',
#  u'amazing great experience in all area',
#  'i a macys credit card holder so either way m satisfied',
#  'app ok but not finding it easy to shop on it',
#  'great app lovo it',
#  'so easy to use love the my wallet feature',
#  u'since the update this app ha been falling apart cannot check my statement or make payment it very irritating',
#  'love ordering from macy love everything buy and their delivery time is excellent',
#  u'navigating the app is very easy love the list option and ordering item to pick up in store on the same day is awesome',
#  u'i love the app it easy to keep up with the sale',
#  u'i find this app easy to use sometimes at the end it can be confusing about not getting reward',
#  'easy to navigate',
#  u'a total waste of my time the associate who tried to help me have the app try to use it to find something in the store it wrong try to scan tag to check out it won enable itself try to use code it say is for woman apparel amoung other item and it won register and full review',
#  'good place but some time chose something with price fixe and when you move in bag the price change that is no fair',
#  'the app seemed to go down on black friday every choice would make would trigger technical issue and not add to the cart',
#  u'great product nice sale',
#  'fast and easy',
#  'it great',
#  'love macys',
#  'great',
#  'i love me some macy s',
#  u'using this app ha been enjoyable it is quality user experience',
#  'very easy app to use thank you macy',
#  'love it all',
#  'not user friendly enough difficulty to create an account',
#  u'app update too often',
#  'love macy s',
#  'great experience always always find what iam looking for',
#  u'this app make life easier',
#  u'love it it doe what it say and it keep all my coupon in one place don have to look for them',
#  u'paying ur monthly payment option are amazing so much better not standing in line to make payment love it',
#  'wonderful',
#  'great app for faster shopping from anywhere',
#  u'i wa looking for dress and it gave me wide selection that is important',
#  'very convenient and easy to use',
#  'easy easy easy',
#  'i love this app',
#  'iove shopping at macy s',
#  'pretty good app easy to shop for everything need',
#  u'it just keep saying download pending',
#  u'i find the macy app easy to use and navigate with very few issue',
#  u'everthing is easy to use and wounderful great deal all the time love macy',
#  'a lot of good stuff',
#  'easy to use',
#  'couldn get signed into my account so deleted the app',
#  u'great it is very convenient ve used it for most of my purchase and it is easy to navigate love it',
#  'easy to use and use it frequently',
#  u'very good wish they can add age to the boy tab',
#  'only had it week or so but so far so good',
#  'please allow app to be moved to the sd card other than that excellent app',
#  'so easy to use love this app',
#  'love maycy s',
#  'great',
#  u'update doesn work and then block app from operating',
#  u'this app ha everything that make it easy for me to check my account balance send me alert canoe sale etc',
#  u'app never worked correctly customer service couldnt help and now m inundated with email thanks so much',
#  u'great app and love the deal',
#  'easy to use very convenient',
#  'it would not let me long in',
#  'always crashing and logging me out',
#  'not too bad',
#  'i absolutely love love love',
#  'easy to navegate',
#  'app is great and easy to use',
#  u'easy a 123 order',
#  'i love macy s',
#  'i love the macy app',
#  u'wonderful and easy yo use saving right at your fingertip',
#  'good',
#  'easy to use and convenient everything you need including your macy card is one click away',
#  u'i can find 100 cotton lady clothing',
#  u'very easy to use and like the fact that you can pay your credit card right in the app a well',
#  'easy to use',
#  'fantastic in the store and onlineorders',
#  u'make shopping fun conveniently quick it take away all the hassle negative thing that come along with shopping really like how get notification when sale m interested in is going on gave 4 star for not getting fragrance sample with purchase of cologne bottle like do in store full review',
#  'awesome',
#  'awesome app very easy to use',
#  u'it is always great shopping for deal',
#  'really like this app',
#  'very easy to use this app',
#  'love it',
#  'easy to navigate find what need easily',
#  'easy to use app',
#  'very nice website',
#  'very good',
#  'very easy to use',
#  'it always feel good shopping experience',
#  'just love it',
#  'nice',
#  'i love to do my shopping online because can find better item and price for petite in the store so love macy app',
#  u'app crash close on ck out',
#  'easy to use',
#  'i love macy s',
#  'nice and easy to use',
#  'my favorite store',
#  u'i love the app because it show everything you could need it is in beautiful display',
#  'very user friendly',
#  u'great app great saving',
#  u'always good offer and price',
#  'i love it',
#  u'love macys appt always ha great deal',
#  u'love it find more than what wa looking for',
#  u'this is great app for shopping checking out the latest sale and promotion and doing price check in store',
#  u'macy app make my christmas shopping easy and it suggests all discount coupon available love love this app',
#  'i love this app it very convenient',
#  u'i love macy store especially beauty department',
#  u'i like the app really need to be able to save the search filter the reason is shop the same brand and size instead of constantly have to reselect the filter over',
#  'love this app',
#  u'this app is joke have never not once been able to log into my cc account it just constant loop of waiting for successful log in which never work',
#  'love the app',
#  u'easy to use and compared to the apps of macy competitor the speed in which you are able to make color or stlye comparison make shopping on the app fun and show respect for the customer time you can also filter and sort item without having to watch paint dry in between',
#  'easy to use',
#  'excellent should have gotten it while back',
#  u'need better user interface and app freeze constantly',
#  'love my macy app',
#  'i just love not having to drive to what want',
#  u'everything have experience with macy ha been awesome',
#  'great app',
#  'love this app',
#  'need pay online process',
#  'cannot get ad off an unrelated app bad',
#  'i love macys',
#  'quick and awesome way to do some shopping',
#  'awesomeness',
#  u'i am able to order item love 1',
#  u'i prefer using the website v the mobile app because can empty my shopping cart because of erro message',
#  u'have not use the app a yet so can answer the question the question should come after the app ha been used how can you rate some thing you have not used',
#  'it is good app just wish it let you highlight the tracking number so you could put it in browser',
#  '',
#  'love the app',
#  'i love to shop online',
#  u'horrible cant check out it keep saying error enter shipping address and have even tried different address and it wont work',
#  'very good at all',
#  'each time try to use app it is unavailable',
#  u'love this app scanning price getting alert on price drop is great',
#  u'love this app simple to use and it actually work',
#  u'very slow creates blank page kick out of the app',
#  u'i love using this app because it so easy to use and it alert me regarding awesome sale and promotion',
#  u'everytime start browsing it show some item and then stop so if it suppose to display 100 it only show 30 and it won scroll down anymore it doe it every time it annoying',
#  'easy to use',
#  'this app brings shopping at your door step',
#  u'list issue continues first three list are the only available when click on add to list reinstalled app and the issue remains',
#  'very happy with the cosmetic department',
#  u'app not working properly unable to empty bag a needed',
#  u'i love to shop in macy because of the good sale price that you have in every department and the quality of the merchandise',
#  u'not being able to see the picture of the item is really saving me lot of money am faithful shopper of macy online hope you guy get this problem fixed soon',
#  'great app and very easy to use highly recommend it',
#  u'ordered from app which worked well had return and couple exchange online site wa unavailable and nothing on app to handle problem spent over an hour on phone straightening everything out not user friendly process',
#  u'i love this app it is very informative use this app often there are many item and easy to navigate',
#  'need to update real time account summary otherwise could use the internet to view product',
#  'i hope dont regreat updating this app that usually jack up your phone some how',
#  'great',
#  'love it can find everything need',
#  u'love shopping for discount price thank you',
#  u'they told me if download macy app get 25 on my next purchase but that wa lie',
#  'it is good',
#  u'i have had no problem using this app can quickly narrow my search and it show me what am looking for',
#  'easy and convenient',
#  'great place to shop',
#  'i love it',
#  'doesn seem to work very often',
#  'very comfortable easy to use',
#  'it easier than going to the store when you can get there',
#  'updated app now it wont let me sign in',
#  'love it',
#  u'easy but do not like when you have item in your cart and when you get ready to purchase they have to be removed if you re not buying all amazon save for later purchase',
#  'excellent price good store',
#  'exceptional app easy to use',
#  'can view credit card information',
#  'excellent mascara eyeliner lipstick or lip gloss',
#  u'love everything in one place eg acct purchase history order etc see pic of order with detail',
#  'can not sign in because forgot password can get reset from tech support',
#  u'good sale',
#  'like everything and want',
#  u'absolutely satisfy tank macy s',
#  u'i love macy ad clothes',
#  u'sometimes it work sometimes it doesn t',
#  u'i cannot open this app since the new update do most of my purchase this way',
#  'i love macys',
#  u'able to view image initially after search but once you click on product your unable to see anything it difficult to shop online when you can see image option',
#  'i absolutely love this app it so awesome',
#  'i like it very useful',
#  u'i love to pay my credit card until it time to pay this one the worst payment platform ever',
#  u'crash every time try to launch the app hey macy how do you expect to have any customer retention if we can launch your junk app',
#  'love everything macy',
#  'nice and convenient',
#  'useful app',
#  u'easy to shop at macy the app is quick to manipulate when shopping in various department',
#  'great app would rather shop through the app then go to the store',
#  u'incredibly buggy and constantly needing update but update don help it the worst way to keep track of your macy card',
#  'i think it great can see what want before go into store',
#  'good app',
#  u'the app crash lot',
#  'l love this app very easy',
#  'easy convenient',
#  u'love it make picking up the order even better',
#  u'the way they serve like human being',
#  'really great customer service',
#  'i love macy s',
#  'very simple to use',
#  u'it wa working but the past 3 update made it crash everytime ive opened the app please fix this soon miss using the app so much',
#  'love this app',
#  u'it actually make shopping at macy easy and enjoy good deal',
#  u'always easy to find what im looking for and purchase are easy great on line selection',
#  u'app doesn allowing you to see saving until checking out plus 20 in store pick up not applied',
#  u'wa nice helping me with the detail and will be in touch when get back from the store thanks for your help and you are the best at store spent time with interested in that customer also doing good job with me and they are all in the same',
#  'great and convenient just love it',
#  'i love macy s',
#  u'i just love macy you can always get name brand in clothes bed clothing last forever shoe are awesome when go to macy it feel so good just to be there magic world',
#  u'user friendly app do have bar code scanner a well that help once you visit the store',
#  u'love the app very practical very convenient cause can shop where ever m at easy to use and love that can use my coupon have saved',
#  u'this app save me great deal of time very useful',
#  u'it very good app you check all you want to buy',
#  'i always shopped at the macy store',
#  'everything is good but would like if the wish list didnt refresh to the top everytime you make an update',
#  u'easy to use able to shop make payment and track package for delivery',
#  'macy is the first place go when need something m plus size so online shopping is my go to love macy app',
#  u'i find pricing is high even on item listed on sale item on clearance a well a item which list a discontinued quality of stock macy carry is surperior which speaks for higher pricing',
#  u'used to work just fine few year back now it shuts down when trying make payment',
#  'i love this app',
#  u'the best of best stuff with best of best deal one can get here and',
#  u'i shop at macy frequently macy ha good quality in everything they have love shopping at macy online and in store',
#  'great',
#  u'image are not showing when item is clicked to get detail',
#  u'this app is pain to navigate have to navigate through 3 different screen just to get to the payment center',
#  'convenient love it',
#  u'update have ruined what used be great app',
#  'i never got 25 off coupon and this is my first time ever installing the app',
#  'love macys always getting good stuff',
#  u'a great app get the best sale and wend go to the store do great save alot sweater shirt pant sneaker brand name jean shirt save alot so what you waiting for go for it maycs thank you julio herrera bronx ny',
#  'doesn load the page',
#  'the app will not open',
#  'it so easy to use on my phone',
#  u'doesn fit well on android tablet photo are distorted',
#  u'love all the option to choose from plus great quality',
#  u'item were quite easy to find',
#  u'so easy to use and such great variety in all category',
#  'love macy and the app itself is nice and easy to use',
#  u'i love this app can keep an eye on my jean then buy when they go on sale also find thing online before see them in the store have the item shipped to me you can have them shipped to the store if you wanted',
#  'macy is my favorite place to shop',
#  'good app',
#  'this latest app update is so much better than in the past can do just about anything including return thanks for listening macy',
#  u'app stop loading result after 20 or so',
#  'ok',
#  u'it one of the best shopping apps ive been on and of course it the best cuz it macys',
#  'it is very reliable',
#  'crashing on android',
#  'macys and macys app',
#  'the app is cool',
#  'very handy love it',
#  'good',
#  'i love macy s',
#  'this app is poorly done',
#  u'everyone wa so helpful',
#  'the problem have had is scrolling down to see material content sometimes it is below the line and wont allow me to scroll down',
#  'ok',
#  'everything is perfect',
#  u'online shopping is easy no issue however have tried the in store shopping feature more than once in more than one macy and it doesn work freeze when scan an item',
#  u'the assistance you receive is outstanding make shopping at macy stand out from the rest',
#  u'it wa very convenient wa promised 25 off my order for downloading the app which didn work contacted customer service and representative helped get the discount not until said wa uninstalling the app',
#  u'bad macy storefront is good but the website is slow',
#  u'it great',
#  'very easy to use',
#  u'too many notice too intrusive',
#  'excelent for everything',
#  'excelent',
#  'love this app m always shopping',
#  'love macy',
#  u'i find what want easily even thing don want but need at the time see them love the ability to pay my bill from the same place',
#  'love this app so easy to use',
#  u'love it the app make shopping easy and love the price finder when you are shopping in the store just scan the tag and it will tell you the sale price',
#  u'great shopping lot of choice easy fast and quick transaction love it',
#  u'it wa great but it stopped showing image recently',
#  'terrible am unable to make purchase',
#  'best ever',
#  'love macys',
#  'this app is very useful',
#  u'the conveneience and lot of deal',
#  'macy always good',
#  'love this app',
#  u'since live far from macy i use this app to help me shop for thing that would mormally have to drive long distance to the store for',
#  'i like this app because always can find everything',
#  'i iove macy they are so helpful and always have what need',
#  u'i work at macys and love this app a customer and employee use it for everything highly recommend more people take advantage of the scan and pay it make checking out at the register much faster',
#  u'make shopping at macy almost too easy app function well and ve rarely been frustrated prefer it over the website',
#  'i love macy s',
#  'use it allthe time',
#  'very handy app',
#  u'great view of item in my dept',
#  'very good love it need catalog can you sent me one very month please',
#  'excellent',
#  'fast and easy to use',
#  u'i love it it easy and convenient for shopping everything needed got it and it wa ok',
#  'nice app can get everything that need without stepping in store',
#  'excellent',
#  'great great great',
#  u'need more filter and direct input for search',
#  'great',
#  u'wonderful for on the go shopping but really helpful for in store use if don have time to try on item just scan the tag and view it on model great too for ordering size on the spot should the size not be in stock at the store all good thought and compliment to the developer of full review',
#  'very comfortable using it',
#  u'too frequent required update which mean bad app design otherwise good',
#  u'love love macys the app just make it easier for me to shop whenever choose',
#  'good',
#  u'easy to use show sale price and all available size',
#  'always there',
#  u'it is the quickest way to shop and track order',
#  u'i ve had difficulty lately have had to shut down and start over during various attempt to place an order or browse',
#  u'it wa great',
#  u'just for browsing or shopping macy app make my online shopping experience enjoyable',
#  'always good experience',
#  u'take you thru too many change just to get information about your purchase',
#  'love it very convenient',
#  'love the app',
#  'i love this app',
#  'nice store with great experience',
#  'easy to buy easy to use and best is that remembers my information',
#  u'it easy to shop get just what expected love the sale reward too',
#  'one of the best',
#  u'this app hardly work it always something for month it wa error now it won completely update i have item in my bag ll probably have to reshop',
#  'easy to use',
#  u'it good for the most part just freeze alot',
#  u'it nice to pre shop and find item in store',
#  u'first time buying online so this app helped direct me to doing it correctly let hope so',
#  'i like everything in macy s',
#  'just love macy s',
#  u'great deal',
#  'special using online shopping',
#  'i like it it is convenient',
#  'user friendly and easy to navigate website',
#  'very good app keep up the good work',
#  'love it',
#  u'it easy to check the price with this app',
#  'best experience ever',
#  'l enjoy shopping at macy s',
#  '4 very good store',
#  'love it',
#  'love the easy way can shop from almost any location',
#  'nice',
#  u'terrible app couldnt even search for what wa looking for no filter',
#  'very organized',
#  'very reliable store all you can find here with great price and nice people',
#  'very good app',
#  'i enjoy shopping at macy department store on the sale day s',
#  u'love the app have been shopping with macy for decade love the mobile app so easy to use',
#  'always have problem whenever open the app require update and your service is run out of time',
#  'exceptional each every time thank macy',
#  'this store is the best',
#  'very convenient good customer service and quick response',
#  'best app ever very helpful',
#  u'always find great price on new clothing',
#  'easy to view order from also like the convenience of viewing or paying my bill',
#  u'macy is great with their selection of item a well a the sale',
#  u'love love love macy quality good at great price',
#  'great price customer service is great',
#  'it helpful',
#  u'i totally enjoy shopping on this site can browse the great deal anytime anywhere',
#  u'i love macy they ve always got anything you need at awesome price',
#  u'love thr deal',
#  'i ve always had wonderful experience with macy whether online or in store',
#  u'app always work navigation easy',
#  'app is very easy to use',
#  'macy the best store to buy',
#  'i love the app',
#  u'great item and easy purchasing',
#  'my favorite store amazon who',
#  u'06 14 2019 after last update app crash whenever try to open macys credit card info',
#  'love macy s',
#  u'i love macys app it ha great ease for searching for product using coupon and your reward',
#  'exactly the way wanted it',
#  'wow the best app',
#  u'it been crashing lot',
#  'very easy to use love it',
#  u'love to shop the app can still get all my discount and easy to return if not right',
#  'love macy',
#  u'the app is great but it doe not show the item that you put in the cart and show the bag empty next day',
#  u'easy to navigate for payment and or shopping',
#  'i enjoy using macy app it so easy to shop',
#  'great app for shopping online tracking new stuff',
#  'outstanding',
#  'my favorite ap',
#  'doesn update been trying to update over week still installing',
#  u'easy to navigate make shopping a breeze',
#  'i like the speed worth it',
#  'love browwesi thruogh app',
#  'i love this app don even go to macy anymore since download the app',
#  'excellent and easy to use',
#  u'love the app able to see price drop and shop any and everything love',
#  'great on sale',
#  'great exspect to hear from me again',
#  'always great',
#  'nice app easy to use',
#  'very easy to use',
#  'complicated app but useful',
#  'good',
#  'great app',
#  'it convenient',
#  'very easy to use',
#  'great experience',
#  'love the app simple and useful',
#  u'ok but need to be bit more user friendly god forbid you have to actually call and talk to representative nightmare',
#  u'nice product',
#  u'shop sale you cannot beat price and quality wish they offered more woman long item 33 35 length in pant and 31 in legging and 50 in maxi dress',
#  u'i love macy and love macy app always have they are just stellar and exceptional company in the midst of everything that wrong with corporate america macy stand alone they are fabulous',
#  'awesome awesome awesome awesome experience macy came through again',
#  'very good condition',
#  'easy to use',
#  u'great sale for the purchase good quality item',
#  u'lovely set great deal with screw back',
#  u'i have loved macy for many year this app is very easy to use and very convenient',
#  u'so easy to open this app click on my favorite item all done in just couple of minute',
#  'always great experience',
#  'i like all the merchandise',
#  u'it fine to use in order to pay my credit card explore offering however found it lacking in functionality at the store 1 app doe not work with in store wifi 2 on my last visit to the store wanted to confirm of there a sale price for the item had settled on the app scanner did full review',
#  'love macy s',
#  u'first of all macy is joke wonder what idiot come with 25 off if you have the app and oh wait we get to choose on what merchandise you use the 25 off mean this is joke have never been so disappointed m going to take it off my phone immediately since you guy get to choose on what full review',
#  'easy to use and very helpful',
#  'can get signed into the app',
#  'love the store',
#  u'macy explanation on the this site are so clear precise and tempting you feel it is difficult to pas up their opportunity margaret dalvi',
#  'i love it',
#  'it easy to use',
#  u'i used to love it for yr but for awhile know when you try to read description of item it doesnt go down enough to read the whole thing alot of the time also to look at your on line purchase order you cant open but the last one iv tried deleting and reinstalling and made no difference also the full review',
#  'easy to use',
#  'i love macys',
#  u'easy to find item',
#  'so far love the app but comparing it with other retail apps feel there is room for improvement',
#  u'i love the macy app it been super useful and navigate it without struggle it user friendly',
#  'macy is my favorite store',
#  'great app from my favorite store',
#  'easy to use app',
#  'downloaded app for discount and did not get',
#  u'very easy to use and love the sale alert with thing like',
#  u'quick delivery 1 even came before they said it would and the product are great quality',
#  u'keep closing when try make purchase or pay my balance',
#  u'so in love with this app make my life easy very easy to manage love it',
#  'easy to find what am looking for',
#  'i like good smell of cologne',
#  u'certainly one of the most useful apps make shopping lot easier',
#  'very satisfactory',
#  'amazing',
#  u'easy to set up you can check the merchandise availability while you re in the store simple process for shipping a well fantastic',
#  'wonderful my favorite store to shop',
#  'have good quality stuff',
#  u'i bought dress on line and ehe received the dress it wa totally different from what saw on line',
#  u'i love the deal find at macys very convenient return and great customer service seen some of the neg review and wonder if they re fake a ive had completely opposite experience app always remembers me and my preference and it done an excellent job of filtering search result love it full review',
#  u'plus size dress',
#  'love the macy app',
#  u'a lot of option doesn work correct',
#  'love it',
#  'i love macy',
#  u'this app is easy to use wish item had more specific information for example garment steamer are described a potent and commercial grade how much power doe that actually translate into cotton is really hard to steam thoroughly not enough info',
#  'i can shop easily',
#  u'if it worked all the time d give it 5 star but for the last few month it seems like there always an issue with something either it wont open can access my account or use my star money please fix it ll change it to 5 star unfortunately since the latest update it worse a of full review',
#  'too amazing can stop shopping',
#  'it really good like it make shopping easier',
#  'my favorite way to shop',
#  'love this app',
#  'i always satisfied with everything buy at macy',
#  u'just perfect and efficient let me take advantage of the special sale without leaving my house what else could ask for',
#  'awesome and easy to click through',
#  u'cannot remove item from bag or checkout therefore cant mk the purchase want',
#  'the macy app is very easy to use',
#  'can edit your review',
#  'user friendly',
#  'macy is the number one store',
#  u'find great deal',
#  u'the best brand',
#  'i find it easy to use',
#  'this app is great never have any problem when im shopping',
#  u'convenient had minor glitch when entering required information before placing order',
#  u'very user friendly ha all the info you need it also give you the option to scan barcodes from the store',
#  'my experience with macy is excellent',
#  'it great and applicable',
#  'great',
#  'good',
#  u'awesone and the extra 25 make it even better',
#  u'great deal and great app',
#  'since the update m not able to see the item once select it',
#  u'no white wedding dress',
#  u'there no better app with more benefit',
#  'easy to navigate',
#  'great app',
#  'i love how easy it is to navigate through this app',
#  u'i love the macys app it very convenient',
#  'love macy',
#  'i really love macy period',
#  'this app is easy to use',
#  u'love this app easy to find the designer you love and shop them create list of item you would like to buy and put them on your list go straight to your list on any visit receive email of item on your list that go on sale love macy',
#  'good',
#  'easy to use great accessibility',
#  'app is only vertical on my mobile device',
#  'live for macys',
#  'it easy like it',
#  'i love macy and the app',
#  u'app will not filter item',
#  'if something is wrong easy to return',
#  'very good app',
#  u'it great except the point issue thats confusing for ppl that dont pay attention to every little detail about how to exactly get star award mean come on it the holiday who ha time to recheck and make extra sure ur logged on to 2nd and different program in order to get point in the star awa full review',
#  'good place to shopping',
#  'affordable and great quality',
#  u'very unfriendly to open monthly ststement is impossible mainly use this app to make payment and that a struggle if you want to get aggrevated by all mean download this app',
#  'i love macy',
#  u'love how easy shopping ha been this holiday season',
#  'quick fast and great love it',
#  'found great bargins nice clean store super kind service',
#  u'always easy to order or return item it wonderful shopping on line with them',
#  'love it',
#  u'app quits after several minute of use almost every time use it',
#  'love macy and this app',
#  'i have had continual exceptional experience each and every time use this app',
#  'macy love',
#  u'love the website but when it come to coupon you can use them on perfume know other store like dillard you know store compatible to macy they allowed their store coupon to be used on the perfume department',
#  'always have what need',
#  'worst app ever can login to my account or shop for anything',
#  'love it all',
#  'very easy and simple',
#  'excellent',
#  u'quality item and amazing sale',
#  'real good app',
#  'so easy to use',
#  u'doesnt find correct location doesnt load all product website isnt much better but this is horrible',
#  u'very convenient and easy to use love it show you the latest offer on wide variety of item',
#  'much improved from just the website still love shopping at macy s',
#  'i love macy s',
#  'i just love it',
#  'is good like it work',
#  u'ever since last update m not able to see pic of item that search or are interested in buying please fix',
#  'love this app',
#  'the app is helpful',
#  'the best service and faster',
#  'barcode scanner doesn work but still love using it',
#  u'work fast easy to use',
#  'love the easy home shopping the dilivery is always fast',
#  u'i love macy they are my go to for many thing',
#  u'my favorite place to shop for heel',
#  'when tried to purchase something using my giftcard it would not allow me to',
#  'very good app easy to move and fast to search',
#  u'macy is one of the most fashionable department store for woman of all size',
#  'good',
#  u'i wa so excited to order from this app since the macy closed near u ordered size 6x girl nightgown d boy 2t for christmas which the girl ended up being out of stock on the the 23rd received an email that they apologized for it should have been to me on the 18th they gave me th full review',
#  u'always get the best deal',
#  'phenomenal',
#  'very user friendly',
#  u'it took me while to get what wa looking for but wa able to find two of the three item wanted',
#  u'the app is convenient receive the same store discount a would if were in the store',
#  'excellent',
#  'i am shopping lover but this app is nicely built great web designing',
#  'excelent service and great offerts',
#  'amazing',
#  u'great app let me know when item have on my wish list is on sale and give me notice when macy is having sale',
#  'love macys great app easy to use but also slightly problamatic for my wallet because it is too easy to shop with one click to checkout lol',
#  u'great merchandise awesome sale and perfect customer service absolutely love macys',
#  u'great product at macy always',
#  u'frequently have problem with valid password not being accepted make new password and get into the site next time same problem never have this happen with any other site',
#  u'macy ha everything need for my wardrobe and home',
#  'i love this app use it all the time',
#  'i love shopping macy s',
#  'easy to use',
#  'won let me shop',
#  'exelent',
#  'excellent',
#  'app is convenient but had glitch when ordering would not recognize my valid email for purchase',
#  'terrible pop up disrupted my shopping',
#  u'love it do not use the app a my main source for ordering use the website for that but love to pull up the app while am out and about to check on item and see what new also love to window shop when have few minute to spare open the app pin down the search option last act full review',
#  'love this app',
#  'great way to shop',
#  'good',
#  u'it crash for enabling fingerprint account macy credit card enable fingerprint',
#  'it won let me shop online you are missing my money lol',
#  u'one of the best store apps fast quality of graphic easy to navegate love it',
#  'excellent',
#  'very easy and quick',
#  u'check here before you go to prestigious site coach nike etc might find better deal like did yippee',
#  'love the app very convenient to use',
#  'speechless it simply fantastic',
#  'fast and easy to use',
#  u'everything is great except it app doesn show all the product',
#  '',
#  'very very good',
#  u'i thoroughly enjoy this app make shopping convenient especially for working people browse every day',
#  'convince and easy to access',
#  u'update it ha improved greatly doe not crash like it used to be crashing all the time always use the app but lately it kick me out all the time what is wrong please fix it',
#  'i love macy s',
#  u'please could you stop telling me to update every 2 week',
#  'macy and opium are the best',
#  'good very cool',
#  'awesome',
#  'love the app so easy to use',
#  'awesome experience',
#  'great experience',
#  u'to many ad between scrolling and looking for what you want but the quality merchandise is very good',
#  'easy to ordering',
#  u'site wa informational also appreciate the option to pick up in store 34th is bad option tho selected them before and wa not able to get my purchase this wa during the holiday time tho',
#  'update every month',
#  'love the app and love the store',
#  'easy shopping online 10',
#  u'macy is great place to shop and great opportunity and quality good that last',
#  u'app doe not let me do store mode and pay doesn let me remove stuff from my basket so cannot do online order too',
#  'love love love macys',
#  u'everything is one click away love the convenience of the selection at hand',
#  'easy to navigate',
#  u'overall pretty good sometimes app ha error or delay',
#  'i wanted to get uggs but macy is too expensive',
#  u'one stop shop for all clothing need',
#  'easy to check out and fast delivery',
#  'app not working thats why gave them one star',
#  'since the march update m unable to use it',
#  'easy shopping macy got everything',
#  'i love this app and love macy',
#  u'it wa fine',
#  'i love macys app',
#  u'i like the app but made me get late payment because the app wa not pulling up the payment page',
#  u'the app is very easy to navigate it run smoothly love macy app',
#  'good',
#  'this is wonderful app it so easy to understand and use did most of my christmas shopping here',
#  u'macy is great their app track everything you view which is super helpful to me the ability to make list for each person by name is the best',
#  'easy to use',
#  u'love the wallet small enough to fit on my crossbody handbag',
#  'easy and quick',
#  u'love my macy app can take advantage of the the flash sale',
#  u'need to improve the statement to see what happen in our account at least the next day of we purchase or return an item',
#  u'macy sppt made it easy to find my product thank you at macy',
#  u'picture want show once try to view please help',
#  u'worst service ever can get my reward money worst app ever everything is fake none coupon are working if you call them they said system error cant help macy differentiate between member customer and non member customer',
#  'so easy and fun have it shipped or pick up in the store',
#  'found it to be very helpful',
#  'i just love macy s',
#  'ease of use',
#  'love the store',
#  'a little tricky to navigate back',
#  'alway had an easy time with macy app',
#  'the best for every day',
#  'love it so convenient',
#  u'easy fun and so many item',
#  u'i love the convenience the shipping take while though',
#  'hi love you macy s',
#  'the easier it is to order the more will buy',
#  'you couldn do any better o',
#  u'excellent service by staff and beautiful selection of item in department store love macy thanksgiving parade they begin the holiday season for me at their parade magic believe',
#  u'easy to navigate great online shopping and great selection well categorized',
#  'love macy yeees',
#  'love having everything in one place',
#  'i like it easy way',
#  u'order not fufilled ive placed my order 3 time to be picked up at different location said not available all store never received my pruduct 2email said they couldn fulfill my order 2 3hr after placed my order the last time called by phone to check if the product is in stock they advis full review',
#  u'easy to use the list option along with the capability to create board share them make shopping for gift so much easier great feature',
#  u'i love macy store it the only online store shop thank you chanda ramirez',
#  'i love it and it convenient',
#  u'i received prompt service from diligent and experienced employee who assisted me in getting what wanted in good time macy ha ever been my best choice for shopping',
#  'i love it',
#  'my favorite place to shop',
#  'great app easy to use',
#  'using this app is wonferful',
#  u'they always have variety of item to choose from to get the best their price is good and get good customer service',
#  'excellent',
#  'excellent like it',
#  'love macy s',
#  'i love is is so convenient for me last minute gift',
#  'love it',
#  'i love this app',
#  'love it',
#  'this amazing application',
#  u'the only reason shop this app is that return are easy and there are great sale the app consistently fails to show the full description and info of item the info that is available for item is typically incomplete e no info on what type of material is it stretch who know m not mad full review',
#  'easy to use and fast check out',
#  'misleading since you don get to choose what you get to use the 25 off of',
#  'redesign the app',
#  u'great app enjoy shopping and easy to use for paying my payment',
#  'awesome',
#  'easy to use and 25 off coupon for downloading',
#  u'pick up in store keep saying error',
#  'best of all store apps',
#  'must have',
#  'great app',
#  'love to use this application easy to use',
#  u'it awesome love it',
#  u'to find thing from store to website use web id',
#  'always excellent in my top 3 of shopping apps',
#  u'this app keep crashing not cool',
#  'macy is favorite store',
#  'i like shop online like macy',
#  u'love macys customer service people they always work thing out for me',
#  'update ruined my experience imagine if you could not view the product you want to purchase or unresponsive app fix this please',
#  u'this app is actually better than the other men store that purchase from frequently',
#  'wonderful shopping experience',
#  'macy is always great',
#  u'love the price and discount',
#  'easy to navigate',
#  'love it easy to use',
#  u'very nice keep getting better',
#  'easy to use',
#  'my go to for great macys shopping experience',
#  'very good app easy to use',
#  'awesome thanks so much for all',
#  u'work everytime',
#  'it so easy to use checkout is smooth and very convenient totally love it',
#  u'i always shop from it but it freezez lot and wish the description especially with color is more accurate good app',
#  'qq',
#  'great app',
#  u'macy app rock',
#  'i love macy s',
#  u'i just love the macy app it good wonderfull to shop with good price and many other thing that you can fine on the app you just have to try it',
#  'very good liked',
#  'easy to use pretty basic',
#  'great app keep up the good work',
#  'i just love it',
#  'terrible',
#  u'sale price are great',
#  'good',
#  'i love macy s',
#  'i love it so easy to window shop on my cell',
#  'great and easy to use',
#  'i love macy',
#  'convenient and user friendly',
#  u'pretty good app overall just don like that sometimes it ll say you have 1 000 item in category but when you scroll to view it only let me view like 100 item and there wasn a view more button have not made purchase through the app yet though',
#  'excellent',
#  u'most convenient place to shop with easy navigation good description and very good deal overall very good customer service thats if ever need one',
#  'easy to work with love it',
#  u'this macy app ha been super handy when taking quick look to see if an item is available or remind me of my credit card balance before get to my desktop so glad this app is available',
#  'very good fast shipping thanks',
#  'great app easy to work with macy love this store',
#  'good',
#  'i appreciate this app because it is simple to follow and fast with updating or editing the order',
#  'loving the convenience',
#  'hello this app is awesome and easy to use',
#  'love it so easy to shop',
#  'very happy with this app',
#  'app is very easy to use',
#  'convenient',
#  'i always enjoy shopping at macy and this app made it all easier',
#  'it is so great to be able to order online because have difficulty walking thank you',
#  'great tool price scanning ordering size check other color check amazing',
#  'just signed up but think it made my first transaction easier',
#  'very friendly and ease to browse',
#  u'so far my shopping at macy ha been great no problem at all and they re friendly they re very accommodating to the customer and answer all of your question and just love it',
#  u'my experience wa extraordinary',
#  u'it my favorite store the people are very helpful they have wonderful sale and there always there to help you id recommend it to everyone',
#  u'work better than most retail store apps',
#  'excellent price excellent product',
#  u'i ve been trying to update my account for day so can track my order everytime it start installing get an error this need to be fixed immediately w',
#  'excellent',
#  'the app is excellent',
#  u'sometimes freeze up',
#  u'i in love with the macy app it completely user friendly and so much easier than going to the store and they have much bigger selection online even though my store is one of the bigger one',
#  'great experience',
#  'i love this app',
#  u'doe not work like online search is difficult app keep freezing',
#  u'great information for your home and family member',
#  'i love macy',
#  u'macy ha been my favorite store to shop and now live in cody wy this app ha been life saver thanks so much for making it possible for people who doesn have macy close',
#  u'it keep crashing',
#  'love macys return policy from brick and mortar to online puchases very reliable easy app usage',
#  u'i love you guy',
#  u'i love it easy to shop no waiting in line and easy return',
#  'it work for me',
#  u'great to have at my finger tip',
#  'the best app out there',
#  u'like buying on line and picking up in store also like being informed of sale on item viewed in the past',
#  u'i always thought macys wa too expensive for me to shop there but they honestly arent always find exactly what want and can afford it love macys they have the best deal and know if m buying from macys know the quality is gonna be 10 love love macys',
#  'fast and easy to check out',
#  'the beeeeeeest ever',
#  'a must have app surly will use this app lot thank you',
#  'love it',
#  'great to easy to shop oh no lol',
#  u'love macy and the app make purchasing easy',
#  'excellent and convenient',
#  u'i find great buy at macy s',
#  'love this app',
#  u'the great sale',
#  u'great deal great place to shop',
#  u'couldn see image after updated please fix',
#  u'love this app have had nothing but positive experience with this app',
#  u'i love you this macy app no complaint at all',
#  u'too easy to purchase thing',
#  'i love it easy to manage',
#  u'i love it it super easy and secure to do your shopping it ha lot of sale',
#  u'very nice product',
#  'it amazing',
#  u'app keep getting more fluid dig it',
#  u'macys app make the whole shopping experience even better',
#  'i love macy s',
#  u'when place order on it dont get my star reward point',
#  u'excellent app like when put item on my list then get notification when they go on sale thats why give it 5 star',
#  'no 25 off for 1st app purchase will uninstall immediately hate to be manipulated',
#  'i love this app',
#  u'it great shopping is easy and love the shipping they alert me about what is being shipped and when best of all they tell me that it ha arrived at my residence who could ask for more thanks macy',
#  'i love it tempting though',
#  'i love shopping at macy',
#  'easy to use',
#  'enjoy this apps looking all the time',
#  'totally awesome',
#  u'love the store and sale great coupon too',
#  'great service and selection',
#  'easier than web site',
#  'easy to use',
#  u'unable to change password have tried 8 to 10 time fed up all out of new password love your store but hard to shop online and get discount',
#  'i love it everything about it',
#  u'love this app love the store and easy to use and awesome sale every day',
#  'i just dearly love macy',
#  'easy to navigate the site',
#  u'love it easy to use and loaded with good buy',
#  'can get to do everything need',
#  u'love the special',
#  'absolutely love macy app',
#  'love the app it awesome',
#  u'can see the picture of item',
#  'good',
#  'wonderful convenient important reliable interesting love macys and do appreciate they service',
#  u'i love this app you get alert when sale',
#  'not the best app but not the worst',
#  'good',
#  u'i can browse filter my interest',
#  u'since last update most item wont show picture once selected please fix',
#  u'every month the app need updating',
#  'i love macy s',
#  'easy to use',
#  u'can pay my bill on the app it won click on the account freeze alot need an update fast',
#  'i like to shop at macy s',
#  'enjoyable',
#  'great app',
#  u'good app little slow to return shopping after adding item in cart',
#  u'constantly updating stupid app always need new update before use macy is great macy app suck don want to download new update every time try to use it might a well get an iphone for such an inconvenience device huawei mediapad x2 7 inch greatness',
#  'great tool',
#  'love the app',
#  'i love the convenience of this app',
#  'i love this app',
#  'i love this app',
#  u'filter dont work very slow',
#  'great app easy to use',
#  'super convenient and easy to shop',
#  u'easy to find item great sale promotion',
#  u'fix your freaking app there always we re experiencing technical difficulty error message and can even log in',
#  u'every thing wa of good qaulity',
#  'good easy fast and on time',
#  'love my macys app quick and easy to shop at home or on the go happy shopping everyone',
#  'my favorite store for value and selection',
#  'good service quality ty',
#  u'cant log in to manage credit card',
#  u'is dodo like your fortnite skill boi',
#  'go macys',
#  'love it',
#  'i love this app',
#  u'awesome app it so easy to use and to find what your looking for recommend to everyone',
#  'love shopping on the macy app',
#  u'there ha been frequent occurrence where the app force stop or run very slowly',
#  u'having problem at the check out doe not let to fix the email address',
#  'love this store',
#  u'too many posting of merchandise m not interested in',
#  u'very easy to order product and update of shipment status is great',
#  u'macys ha been around for a long a can remember and they never fail to satisfy love love love it',
#  u'great fast no hassle',
#  'i love the estee lauder team',
#  'love the macy app so easy to use',
#  u'the macy app actually save me money through number of discount and sale item',
#  u'best site to shop on responsive and intelligent inquiry response',
#  u'my coupon rarely work',
#  u'i believe use this app almost daily it great in store feature is perfect used the new scan and pay recently and it is so easy only area where improvement can be made inventory information when shopping noticed item online will show not available at particular location literally have full review',
#  'very good',
#  'i am tired of trying to make it all work',
#  'love the app and macy s',
#  'wonderful love this app easy to use',
#  'get everything wanna do at the store',
#  u'shopping by email is very convenient it give you an advantage of making your selection without entering the store',
#  'love macy shopping for back to school and christmas every year something for everyone on my list',
#  'app always work without any peoblema',
#  'love it',
#  'i love macy my favorite place to shop',
#  'app is clunky and buggy asking for shipping address repeatedly dispute my address being in my profile',
#  'the app is simple to use and very beneficial',
#  'awesome security for my app',
#  u'all department store should have an app like this',
#  'i love everything from macy s',
#  u'macy is great place to shop both online and in store fashionable selection great customer service and prompt delivery am happy to always shop from macy s',
#  'great app',
#  'i love macy s',
#  u'in store don see this from this app am not credit card shopper hence this app is definitely not suited for my lifestyle when bought my mattress for 900 00 cash had to wait delivery took too long hence my decision to remove this app and block email a well nothing ha changed',
#  u'always great sale love the inc line',
#  'brilliant',
#  'faster and more efficient love it',
#  'great and super easy to use',
#  '',
#  'best app ever',
#  u'convenient shopping easy checkout and fast delivery no need to drive to store walk the whole store and then wait in line to checkout app doe almost everything except return',
#  u'helped me save lot',
#  'the app is great to use',
#  'enjoy the convenience to shop',
#  'i love macy',
#  u'wa frustrated disappointed when had spent time loading 5 item in my cart only got 25 off on 1 item it state you ll receive an additional 25 off an order by installing the app this wa not the case waste of my time',
#  'i just love it',
#  'awesome',
#  u'i love browsing the sale',
#  'great',
#  'my favorite store',
#  u'great team in all department hawaiian style thank n jesus love too',
#  u'i personally think macys is the best for shopping good quality and great price thank you macys munce',
#  u'spam and more spam this app sends you so much advertising that im going to delete it after this review btw set it not to send me email and got even more lol',
#  'very easy to use love this app',
#  u'i love tho app it ha improved my shopping experience tremendously',
#  'package coming on time and easy to track',
#  'can download',
#  u'since update app doesn show picture on homepage have to click on star to actually see what item look like',
#  'i love this app super convenient',
#  u'embarrassingly bad app guessing that it wa created by someone idiot brother in law clunky and annoying to use the filter activity are egregiously horrific in particular',
#  'i like it so easy',
#  'i love macy please don ever close',
#  'this app is way to easy to use have spent more money in the last month at macy then did all of last year so you have been warned lol it is very helpful and fun',
#  'can never get this app to open when try to order',
#  'im having hard time checking out with gift card',
#  'love it',
#  'terrible',
#  'so easy',
#  u'i love it always make my purchase the local store and is great this will be my first time using this app thank you',
#  'fabulous',
#  u'good thing to buy',
#  u'the best love being able to get what need for work all the style are beautiful and pricing is great always deal going on',
#  u'very poor quality scrolling barely work click are registered in the wrong place and some link can be clicked at all the app is also extremely slow and full of an excessive amount of popups had to close about 5 popups before could get to my macy card statement',
#  u'great app easy to use and never have problem with bug or anything with the app great job with the app macys',
#  'macy my most favorite',
#  '',
#  u'it helpful',
#  'love how easy it is to use',
#  u'you can beat macy for great service and sale',
#  u'very user friendly keep you updated with current sale',
#  u'easy to use organized by category sale are up to date search yield high related result',
#  u'it ha everything',
#  'love it',
#  u'pretty easy to navigate the app just disappointed in the coupon that do not ever seem to work on any merchandise need or want guess that more store company issue than an app issue',
#  'easy to use shop and buy',
#  'i love shopping with macy',
#  'easy to use',
#  u'great very happy with all past order',
#  'very easy to use',
#  'keep having to update file whenever it is time to use',
#  'great app you can do lot of different transaction',
#  'i like this store',
#  'nice and multifunctional it can find the product you want even if it out of stuck',
#  'great merchandise and customer service',
#  'i absolutely love this app',
#  'i been trying to buy something and it doesn let me do it very disappointing',
#  'my happy place',
#  'fantastic easy to use navigate',
#  'favourite store just got better for me lataz',
#  'fun and easy',
#  'this is the best department store app have ever used',
#  'great experience love macy s',
#  ...]

# %%
# Convert text documents into corresponding numerical features using Bag-of-Words
from sklearn.feature_extraction.text import CountVectorizer  
vectorizer = CountVectorizer(max_features=500, min_df=5, max_df=0.7, stop_words=stopwords.words('english'))  
X = vectorizer.fit_transform(documents).toarray()

# %%
# Convert values obtained using the bag of words model into TFIDF values
from sklearn.feature_extraction.text import TfidfTransformer  
tfidfconverter = TfidfTransformer()  
X = tfidfconverter.fit_transform(X).toarray() 

# from sklearn.feature_extraction.text import TfidfVectorizer  
# tfidfconverter = TfidfVectorizer(max_features=500, min_df=5, max_df=0.7, stop_words=stopwords.words('english'))  
# X = tfidfconverter.fit_transform(documents).toarray()

# %%
# tfidfconverter
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.float64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=0.7, max_features=500, min_df=5,
#         ngram_range=(1, 1), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words=[u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u"you're", u"you've", u"you'll", u"you'd", u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u"she's", u'her', u'hers', u'herself', u'it', u"it's", u'its', u'itself', u'th...', u"shouldn't", u'wasn', u"wasn't", u'weren', u"weren't", u'won', u"won't", u'wouldn', u"wouldn't"],
#         strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
# Divide our data into training and testing sets
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train our machine learning model using the random forest algorithm
classifier = RandomForestClassifier(n_estimators=1000, random_state=0)  
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(X_test)

# %%
# Evaluating model

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))  
print(accuracy_score(y_test, y_pred)) 

# 91.1% accuracy
# Out:
# [[ 50  54]
#  [ 30 867]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.48      0.54       104
#            1       0.94      0.97      0.95       897
#
#    micro avg       0.92      0.92      0.92      1001
#    macro avg       0.78      0.72      0.75      1001
# weighted avg       0.91      0.92      0.91      1001
#
# 0.916083916083916

# %%
# Store model

with open('macys_reviews_classifier', 'wb') as picklefile:  
    pickle.dump(classifier,picklefile)

# %%
# Call model

os.chdir(r'/Users/jpan/Environments/macys_reviews')

with open('macys_reviews_classifier', 'rb') as training_model:  
    model = pickle.load(training_model)

# %%
y_pred2 = model.predict(X_test)

print(confusion_matrix(y_test, y_pred2))  
print(classification_report(y_test, y_pred2))  
print(accuracy_score(y_test, y_pred2))
# Out:
# [[ 50  54]
#  [ 30 867]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.48      0.54       104
#            1       0.94      0.97      0.95       897
#
#    micro avg       0.92      0.92      0.92      1001
#    macro avg       0.78      0.72      0.75      1001
# weighted avg       0.91      0.92      0.91      1001
#
# 0.916083916083916

# %%
y_pred2
# Out:
# array([1, 1, 1, ..., 1, 1, 1])
